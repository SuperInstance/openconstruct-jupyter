# %% [markdown]
# # 02 — Sense Modules
#
# Build and register sense modules.

# %%
import openconstruct_jupyter as oc

client = oc.connect(notebook=True)

# %%
# %%openconstruct --sense vision
# print('Captured as a vision shadow!')

# %%
from openconstruct_jupyter.widgets import SenseShadowWidget

w = SenseShadowWidget()
w.show('<b>Hello</b> from sense!')
display(w)
