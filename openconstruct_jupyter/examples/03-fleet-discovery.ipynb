# %% [markdown]
# # 03 — Fleet Discovery
#
# Explore fleet topology and health.

# %%
import openconstruct_jupyter as oc

client = oc.connect(notebook=True)

# %%
# %%openconstruct --fleet

# %%
from openconstruct_jupyter.widgets import FleetStatusWidget

w = FleetStatusWidget(client=client)
display(w)
w._refresh(None)
