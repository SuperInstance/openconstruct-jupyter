# %% [markdown]
# # 01 — Quickstart
#
# Get started with openconstruct-jupyter in 5 minutes.

# %%
# %load_ext openconstruct_jupyter

# %%
import openconstruct_jupyter as oc

client = oc.connect(notebook=True)
print('Connected!')

# %%
# %%openconstruct --fleet

# %%
# %%openconstruct --tick "Hello from notebook!"

# %%
# %%openconstruct --room my-first-room
# print('This becomes room context!')
