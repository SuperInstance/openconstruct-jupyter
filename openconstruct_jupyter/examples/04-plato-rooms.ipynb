# %% [markdown]
# # 04 — Plato Rooms
#
# Create, populate, and share rooms.

# %%
import openconstruct_jupyter as oc
import pandas as pd

client = oc.connect(notebook=True)

# %%
df = pd.DataFrame({'x': [1,2,3], 'y': [4,5,6]})
tile = oc.from_dataframe(df, name='sample_data')
print(f'Tile CR score: {tile.cr_score}')

# %%
# %%openconstruct --room analysis-room
# room = client.load_room('analysis-room', context='Data exploration with pandas')

# %%
from openconstruct_jupyter.room_viewer import RoomViewer

viewer = RoomViewer(client=client)
display(viewer)

# %%
result = oc.publish_room()
print('Published:', result)
